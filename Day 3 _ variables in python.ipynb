# %% [markdown]
# # Python Variable
# ## Python Variable
# ### Python Variable
# #### Python Variable
# ##### python variable
# ###### Python Variable
# #######

# %% [markdown]
# # Features in Python
# - Free and Open Source. ...
# - Easy to code. ...
# - Easy to Read. ...
# - Object-Oriented Language. ...
# - GUI Programming Support. ...
# - High-Level Language. ...
# - Large Community Support. ...
# - Easy to Debug.

# %% [markdown]
# ![python-features.png](attachment:python-features.png)

# %% [markdown]
# ![python-features.png](attachment:python-features.png)

# %%
# a = 21

# %%
# rules of variables

# 1>> You can not use any special char in variables
# ~!@#$%^&*()-+={}[];:''""<>,.?/\
full@name = 'Jatin'

print(full@name)
# Out:
#   Cell In[2], line 5
#     full@name = 'Jatin'
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
# rules of variables

# 2>> You can not start variable with digits

1d = 'Rocky'

print(1d)
# Out:
#   Cell In[3], line 5
#     1d = 'Rocky'
#     ^
# SyntaxError: invalid decimal literal

# %%
# 3>> you can use python keywords as a variable

# %%
help('keywords')
# Out:
# Here is a list of the Python keywords.  Enter any keyword to get more help.
#
# False               class               from                or
# None                continue            global              pass
# True                def                 if                  raise
# and                 del                 import              return
# as                  elif                in                  try
# assert              else                is                  while
# async               except              lambda              with
# await               finally             nonlocal            yield
# break               for                 not

# %%
Else = 'Mohan'

# %%
print(Else)
# Out:
# Mohan

# %%
#4>> There must not be any space char b/w variable names

full name = 'Kumar Birla'
# Out:
#   Cell In[11], line 3
#     full name = 'Kumar Birla'
#          ^
# SyntaxError: invalid syntax

# %%
fullname = 'Kumar Birla'

# %%
print(fullname)
# Out:
# Kumar Birla

# %%
# 5>> python is a case sensitive language

name = 'karan'

Name = 'Lalit'


print(name)
# Out:
# karan

# %%
print(Name)
# Out:
# Lalit

# %%
studentname = 'karan'

print(Studentname)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 3
#       1 studentname = 'karan'
# ----> 3 print(Studentname)
#
# NameError: name 'Studentname' is not defined

# %%
# 6>> use can use underscore at any position in variable

# %%
_abc = 'Mohan'

print(_abc)
# Out:
# Mohan

# %%
my_name = 'Mohan Verma'
print(my_name)
# Out:
# Mohan Verma

# %%
employee_full_name = 'Mr Ajay Verma'

print(employee_full_name)
# Out:
# Mr Ajay Verma

# %%
# 7 you can use digit from second position to last one

# %%
name = 'Karan'
name1 = 'Ajay'
name2 = 'Mohit'
name3 = 'Bhaskar'

print(name)
# Out:
# Karan

# %%
print(name1)
# Out:
# Ajay

# %%
print(name2)
# Out:
# Mohit

# %%
# h/w
